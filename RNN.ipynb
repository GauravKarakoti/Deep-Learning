# %%
# Import required libraries
import tensorflow as tf
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, Dense

# %%
# ------------------------------------------
# Step 1: Load IMDb Dataset
# ------------------------------------------
# Keep only the top 10,000 most frequent words
(X_train, y_train), (X_test, y_test) = imdb.load_data(num_words=10000)
# Out:
# ...
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# ------------------------------------------
# Step 2: Pad sequences
# Make every review exactly 200 words long
# ------------------------------------------
X_train = pad_sequences(X_train, maxlen=200)
X_test = pad_sequences(X_test, maxlen=200)

# %%
# ------------------------------------------
# Step 3: Build the RNN model
# ------------------------------------------
model = Sequential()
# Word Embedding layer
model.add(
    Embedding(
        input_dim=10000,    # Vocabulary size
        output_dim=32,      # Embedding vector size
        input_length=200    # Length of each review
    )
)
# Simple RNN layer
model.add(
    SimpleRNN(
        units=32,
        activation='tanh'
    )
)
# Output layer for binary classification
model.add(
    Dense(
        1,
        activation='sigmoid'
    )
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
# ------------------------------------------
# Step 4: Compile the model
# ------------------------------------------
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)
# Display model architecture
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn (SimpleRNN)          │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
# ------------------------------------------
# Step 5: Train the model
# ------------------------------------------
history = model.fit(
    X_train,
    y_train,
    epochs=5,
    batch_size=64,
    validation_split=0.2
)
# Out:
# Epoch 1/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.7340 - loss: 0.5299 - val_accuracy: 0.8146 - val_loss: 0.4192
# Epoch 2/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.7964 - loss: 0.4356 - val_accuracy: 0.7880 - val_loss: 0.4509
# Epoch 3/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.8944 - loss: 0.2593 - val_accuracy: 0.8316 - val_loss: 0.4105
# Epoch 4/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9476 - loss: 0.1500 - val_accuracy: 0.7218 - val_loss: 0.6109
# Epoch 5/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9546 - loss: 0.1272 - val_accuracy: 0.8272 - val_loss: 0.5152

# %%
# ------------------------------------------
# Step 6: Evaluate the model
# ------------------------------------------
loss, accuracy = model.evaluate(X_test, y_test)
print(f"\nTest Loss: {loss:.4f}")
print(f"Test Accuracy: {accuracy:.4f}")
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8254 - loss: 0.5250
#
# Test Loss: 0.5250
# Test Accuracy: 0.8254

# %%
# ------------------------------------------
# Step 7: Predict on a sample review
# ------------------------------------------
sample_review = X_test[:1]
prediction = model.predict(sample_review)
print("\nPrediction Probability:", prediction[0][0])
if prediction[0][0] >= 0.5:
    print("Predicted Sentiment: Positive")
else:
    print("Predicted Sentiment: Negative")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step
#
# Prediction Probability: 0.0016828511
# Predicted Sentiment: Negative
